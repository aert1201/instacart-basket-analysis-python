# %% [markdown]
# # Exercise_4.4_Data_Wrangling_Subsetting

# %% [markdown]
# ## 1. Setup & Imports
#
# ## 2. Import Data (orders.csv, products.csv)
#
# ## Exercise 4.4 – Wrangling procedures (from lesson walkthrough)
#
# ## 3. Initial Data Exploration & Context
#
# ## 4. Data Wrangling Procedures
# # Convert identifier variables to appropriate data types and improve column naming clarity
#
# - Dropping columns
# - Renaming columns
# - Changing data types
#
# ## 5. Data Dictionary (departments.csv)
#
# ## 6. Subsetting Data
# # Create targeted product subsets to support breakfast and dinner-related analysis
#
# ## 7. Exports (Prepared Data)
#
# ## 8. Notes for Final Report
# - Population Flow
# - Wrangling Steps
# - Consistency Checks

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'../02 Data/Original Data'

# %%
df_ords = pd.read_csv(os.path.join(path, 'orders.csv'))

# %%
df_prods = pd.read_csv(os.path.join(path, 'products.csv'))

# %%
df_ords.shape, df_prods.shape
# Out:
# ((3421083, 7), (49693, 5))

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.drop(columns=['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords = df_ords.drop(columns=['eval_set'])

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
df_ords['days_since_prior_order'].value_counts(dropna=False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
df_ords.rename(
    columns={'order_dow': 'orders_day_of_week'},
    inplace=True
)

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_depts = pd.read_csv(os.path.join(path, 'departments.csv'))

# %%
df_depts.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_depts.shape
df_depts.dtypes
# Out:
# department_id    object
# 1                object
# 2                object
# 3                object
# 4                object
# 5                object
# 6                object
# 7                object
# 8                object
# 9                object
# 10               object
# 11               object
# 12               object
# 13               object
# 14               object
# 15               object
# 16               object
# 17               object
# 18               object
# 19               object
# 20               object
# 21               object
# dtype: object

# %%
df_depts.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_depts_transposed = df_depts.T
df_depts_transposed
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_depts_transposed = df_depts_transposed.reset_index()
df_depts_transposed.head()
# Out:
#            index           0
# 0  department_id  department
# 1              1      frozen
# 2              2       other
# 3              3      bakery
# 4              4     produce

# %%
df_depts_transposed.shape
# Out:
# (22, 2)

# %%
new_header = df_depts_transposed.iloc[0]

# %%
new_header
# Out:
# index    department_id
# 0           department
# Name: 0, dtype: object

# %%
df_depts_transposed_new = df_depts_transposed[1:]

# %%
df_depts_transposed_new.head()
# Out:
#   index        0
# 1     1   frozen
# 2     2    other
# 3     3   bakery
# 4     4  produce
# 5     5  alcohol

# %%
df_depts_transposed_new.columns = new_header

# %%
df_depts_transposed_new.head()
# Out:
# 0 department_id department
# 1             1     frozen
# 2             2      other
# 3             3     bakery
# 4             4    produce
# 5             5    alcohol

# %%
df_depts_transposed_new.shape
# Out:
# (21, 2)

# %%
df_depts_transposed_new.tail()
# Out:
# 0  department_id department
# 17            17  household
# 18            18     babies
# 19            19     snacks
# 20            20       deli
# 21            21    missing

# %%
df_depts_transposed_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 1 to 21
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     object
#  1   department     21 non-null     object
# dtypes: object(2)
# memory usage: 468.0+ bytes

# %%
df_depts_transposed_new
# Out:
# 0  department_id       department
# 1              1           frozen
# 2              2            other
# 3              3           bakery
# 4              4          produce
# 5              5          alcohol
# 6              6    international
# 7              7        beverages
# 8              8             pets
# 9              9  dry goods pasta
# 10            10             bulk
# 11            11    personal care
# 12            12     meat seafood
# 13            13           pantry
# 14            14        breakfast
# 15            15     canned goods
# 16            16       dairy eggs
# 17            17        household
# 18            18           babies
# 19            19           snacks
# 20            20             deli
# 21            21          missing

# %%
data_dict = df_depts_transposed_new.to_dict('index')

# %%
data_dict
# Out:
# {1: {'department_id': '1', 'department': 'frozen'},
#  2: {'department_id': '2', 'department': 'other'},
#  3: {'department_id': '3', 'department': 'bakery'},
#  4: {'department_id': '4', 'department': 'produce'},
#  5: {'department_id': '5', 'department': 'alcohol'},
#  6: {'department_id': '6', 'department': 'international'},
#  7: {'department_id': '7', 'department': 'beverages'},
#  8: {'department_id': '8', 'department': 'pets'},
#  9: {'department_id': '9', 'department': 'dry goods pasta'},
#  10: {'department_id': '10', 'department': 'bulk'},
#  11: {'department_id': '11', 'department': 'personal care'},
#  12: {'department_id': '12', 'department': 'meat seafood'},
#  13: {'department_id': '13', 'department': 'pantry'},
#  14: {'department_id': '14', 'department': 'breakfast'},
#  15: {'department_id': '15', 'department': 'canned goods'},
#  16: {'department_id': '16', 'department': 'dairy eggs'},
#  17: {'department_id': '17', 'department': 'household'},
# ...

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get(19))
# Out:
# {'department_id': '19', 'department': 'snacks'}

# %%
df_prods['department_id'] == 19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id'] == 19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks = df_prods[df_prods['department_id'] == 19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_ords['order_id'] = df_ords['order_id'].astype('string')

# %%
df_ords.dtypes
# Out:
# order_id                  string[python]
# user_id                           object
# order_number                       int64
# orders_day_of_week                 int64
# order_hour_of_day                  int64
# days_since_prior_order           float64
# dtype: object

# %%
df_ords_renamed = df_ords.rename(
    columns={'orders_day_of_week': 'order_day_of_week'}
)

# %%
df_ords_renamed.dtypes
# Out:
# order_id                  string[python]
# user_id                           object
# order_number                       int64
# order_day_of_week                  int64
# order_hour_of_day                  int64
# days_since_prior_order           float64
# dtype: object

# %%
df_ords_renamed['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
data_dict.get(4)
# Out:
# {'department_id': '4', 'department': 'produce'}

# %%
df_breakfast = df_prods[df_prods['department_id'] == 14]

# %%
df_breakfast.head()
df_breakfast.shape
# Out:
# (1116, 5)

# %%
df_dinner = df_prods.loc[
    df_prods['department_id'].isin([5, 7, 12, 20])
]

# %%
df_dinner.head()
df_dinner.shape
# Out:
# (7650, 5)

# %%
df_dinner.shape[0]
# Out:
# 7650

# %%
df_user_1 = df_ords[df_ords['user_id'] == '1']

# %%
df_user_1.head()
df_user_1.shape
# Out:
# (11, 6)

# %%
df_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
df_user_1['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 8     3
# 7     3
# 12    1
# 15    1
# 9     1
# 14    1
# 16    1
# Name: count, dtype: int64

# %%
# Step 12: Export cleaned orders dataframe
prepared_path = r"C:\Users\sheid\OneDrive\Documents\Instacart Basket Analysis 01-05-2026\02 Data\Prepared Data"

df_ords.to_csv(
    os.path.join(prepared_path, "orders_wrangled.csv"),
    index=False
)

# %%
# Step 13: Export cleaned departments dataframe

df_depts_transposed_new.to_csv(
    os.path.join(prepared_path, "departments_wrangled.csv"),
    index=False
)
